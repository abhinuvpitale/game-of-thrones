# %%
import pandas as pd
import matplotlib
import numpy as np

# %%
deaths = pd.read_csv('character-deaths.csv')
deaths[:3]
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
#
#    DwD
# 0    0
# 1    0
# 2    1

# %%
deaths.describe()
# Out:
#        Death Year  Book of Death  Death Chapter  Book Intro Chapter  \
# count  305.000000     307.000000     299.000000          905.000000
# mean   299.157377       2.928339      40.070234           28.861878
# std      0.703483       1.326482      20.470270           20.165788
# min    297.000000       1.000000       0.000000            0.000000
# 25%    299.000000       2.000000      25.500000           11.000000
# 50%    299.000000       3.000000      39.000000           27.000000
# 75%    300.000000       4.000000      57.000000           43.000000
# max    300.000000       5.000000      80.000000           80.000000
#
#            Gender    Nobility         GoT         CoK         SoS         FfC  \
# count  917.000000  917.000000  917.000000  917.000000  917.000000  917.000000
# mean     0.828790    0.468920    0.272628    0.353326    0.424209    0.272628
# std      0.376898    0.499305    0.445554    0.478264    0.494492    0.445554
# ...

# %%
deaths.groupby('Gender',as_index = False).sum()
# Out:
#    Gender  Death Year  Book of Death  Death Chapter  Book Intro Chapter  \
# 0       0     10779.0          120.0         1488.0              4126.0
# 1       1     80464.0          779.0        10493.0             21994.0
#
#    Nobility  GoT  CoK  SoS  FfC  DwD
# 0        84   32   45   75   49   52
# 1       346  218  279  314  201  209

# %%
deaths.groupby('Allegiances',as_index = False).sum()
# Out:
#         Allegiances  Death Year  Book of Death  Death Chapter  \
# 0             Arryn       898.0            8.0          143.0
# 1         Baratheon      5984.0           55.0          687.0
# 2           Greyjoy      2394.0           27.0          312.0
# 3       House Arryn       598.0            4.0           29.0
# 4   House Baratheon      1196.0           13.0          190.0
# 5     House Greyjoy      4189.0           36.0          739.0
# 6   House Lannister      3590.0           36.0          446.0
# 7     House Martell       300.0            3.0           70.0
# 8       House Stark      5673.0           35.0          905.0
# 9   House Targaryen      1197.0           13.0          128.0
# 10      House Tully      1495.0           13.0          153.0
# 11     House Tyrell       300.0            5.0           56.0
# 12        Lannister      5386.0           48.0          783.0
# 13          Martell       600.0           10.0           76.0
# ...

# %%
confirmDeaths = deaths[~deaths['Death Chapter'].isnull()]
confirmDeaths
# Out:
#                                   Name      Allegiances  Death Year  \
# 1              Aegon Frey (Jinglebell)             None       299.0
# 3                        Adrack Humble    House Greyjoy       300.0
# 6    Aemon Targaryen (son of Maekar I)    Night's Watch       300.0
# 10                               Aggar    House Greyjoy       299.0
# 12                       Alan of Rosby    Night's Watch       300.0
# 16                            Alebelly      House Stark       299.0
# 22                     Allard Seaworth        Baratheon       299.0
# 24                                Alyn      House Stark       298.0
# 32                         Amory Lorch  House Lannister       299.0
# 39                           Anvil Ryn             None       299.0
# 47                       Aron Santagar        Lannister       299.0
# 56                       Arys Oakheart        Lannister       300.0
# 63                              Bannen    Night's Watch       299.0
# ...

# %%
confirmDeaths.groupby('Gender').count()
# Out:
#         Name  Allegiances  Death Year  Book of Death  Death Chapter  \
# Gender
# 0         33           33          33             33             33
# 1        266          266         262            264            266
#
#         Book Intro Chapter  Nobility  GoT  CoK  SoS  FfC  DwD
# Gender
# 0                       33        33   33   33   33   33   33
# 1                      263       266  266  266  266  266  266

# %%
confirmDeaths.groupby('Allegiances').count()
# Out:
#                  Name  Death Year  Book of Death  Death Chapter  \
# Allegiances
# Arryn               3           3              3              3
# Baratheon          18          18             18             18
# Greyjoy             8           8              8              8
# House Arryn         1           1              1              1
# House Baratheon     5           4              5              5
# House Greyjoy      14          14             14             14
# House Lannister    11          10             11             11
# House Martell       1           1              1              1
# House Stark        19          19             19             19
# House Targaryen     4           4              4              4
# House Tully         5           5              5              5
# House Tyrell        1           1              1              1
# Lannister          18          18             18             18
# ...
